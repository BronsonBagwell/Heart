# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
pwd = os.getcwd()
df = pd.read_csv(r"C:\Users\Bronson Bagwell\Desktop\Finished projects\heart\heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.skew()
# Out:
# Age            -0.195933
# RestingBP       0.179839
# Cholesterol    -0.610086
# FastingBS       1.264484
# MaxHR          -0.144359
# Oldpeak         1.022872
# HeartDisease   -0.215086
# dtype: float64

# %%
df.corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.set_style("whitegrid")
sns.set_palette("viridis")

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
plt.figure(figsize=(16, 8))
sns.histplot(df, x="Age", kde=True, hue="HeartDisease")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(16, 8))
sns.histplot(df, x="RestingBP", kde=True, hue="HeartDisease")
# Out:
# <AxesSubplot:xlabel='RestingBP', ylabel='Count'>

# %%
plt.figure(figsize=(16, 8))
sns.histplot(df, x="Cholesterol", kde=True, hue="HeartDisease")
# Out:
# <AxesSubplot:xlabel='Cholesterol', ylabel='Count'>

# %%
plt.figure(figsize=(16, 8))
sns.histplot(df, x="MaxHR", kde=True, hue="HeartDisease")
# Out:
# <AxesSubplot:xlabel='MaxHR', ylabel='Count'>

# %%
plt.figure(figsize=(16, 8))
sns.histplot(df, x="Oldpeak", kde=True, hue="HeartDisease")
# Out:
# <AxesSubplot:xlabel='Oldpeak', ylabel='Count'>

# %%
sns.countplot(data=df, x="Sex", hue="HeartDisease")
plt.show()

# %%
sns.countplot(data=df, x="ChestPainType", hue="HeartDisease")
plt.show()

# %%
sns.countplot(data=df, x="RestingECG", hue="HeartDisease")
plt.show()

# %%
sns.countplot(data=df, x="ExerciseAngina", hue="HeartDisease")
plt.show()

# %%
sns.countplot(data=df, x="ExerciseAngina", hue="HeartDisease")
plt.show()

# %%
sns.pairplot(df, hue="HeartDisease")

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

le = LabelEncoder()

df["Sex"] = le.fit_transform(df["Sex"])
df["RestingECG"] = le.fit_transform(df["RestingECG"])
df["ChestPainType"] = le.fit_transform(df["ChestPainType"])
df["ExerciseAngina"] = le.fit_transform(df["ExerciseAngina"])
df["ST_Slope"] = le.fit_transform(df["ST_Slope"])

df.head()

# %%
plt.figure(figsize=(16, 8))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
x = df.drop("HeartDisease", axis=1)
y = df["HeartDisease"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.8, random_state=42
)

# %%
lr = LogisticRegression()
model_lr = lr.fit(X_train, y_train)
# Out:
# C:\Users\Bronson Bagwell\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
y_pred_lr = lr.predict(X_test)

# %%
print(classification_report(y_test, pred))
print(confusion_matrix(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83       319
#            1       0.90      0.80      0.85       416
#
#     accuracy                           0.84       735
#    macro avg       0.84      0.84      0.84       735
# weighted avg       0.85      0.84      0.84       735
#
# [[283  36]
#  [ 83 333]]

# %%
lr.score(X_test, y_test)
# Out:
# 0.8380952380952381

# %%
rfc = RandomForestClassifier(n_estimators=300, random_state=42)
model_rfc = rfc.fit(X_train, y_train)

# %%
y_pred_rfc = rfc.predict(X_test)
rfc.score(X_test, y_test)
# Out:
# 0.8625850340136054

# %%
abc = AdaBoostClassifier(n_estimators=300, learning_rate=0.01, random_state=42)
model_abc = abc.fit(X_train, y_train)

# %%
y_pred_adaboost = model.predict(X_test)
print("AdaBoost Classifier Model Accuracy:", accuracy_score(y_test, y_pred_adaboost))
# Out:
# AdaBoost Classifier Model Accuracy: 0.8136054421768707

# %%
gbc = GradientBoostingClassifier(n_estimators=300, learning_rate=0.01, random_state=42)
model_gbc = gbc.fit(X_train, y_train)

# %%
y_pred_xgboost = model.predict(X_test)
print("AdaBoost Classifier Model Accuracy:", accuracy_score(y_test, y_pred_xgboost))
# Out:
# AdaBoost Classifier Model Accuracy: 0.8136054421768707
